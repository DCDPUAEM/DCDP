# %% [markdown]
# <a href="https://colab.research.google.com/github/DCDPUAEM/DCDP_2022/blob/main/04%20Clasificaci%C3%B3n%20y%20Agrupamiento/notebooks/04-Comparacion%20Modelos%20Lineales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparación de métodos lineales

# %% [markdown]
# En este ejercicio vamos a comparar la clasificación y las fronteras de decisión de los clasificadores lineales que hemos visto: Discriminante lineal OLS, SVM kernel lineal y el Perceptrón lineal.
#
# Para esto, vamos a usar estos clasificadores en el mismo conjunto de datos. Después, compararemos la frontera de decisión.

# %%
from clasificador_lineal import LeastSquaresClassifier

'''
IMPORTAR EL CLASIFICADOR DE PERCEPTRÓN
'''

# %% [markdown]
# Definimos el conjunto de datos, usaremos alguno de los datasets *artificiales* de scikit-learn: `make_moons`, `make_blobs`, `make_circles`.

# %%
from sklearn.datasets import make_moons

x_train, y_train = make_moons(n_samples = 120, random_state=89,noise=0.1)

#--- Lo graficamos para verlo ---
plt.figure()
plt.scatter(x_train[:,0], x_train[:,1], c=y_train)
plt.show()

# %% [markdown]
# ## OLS

# %%
'''
Realiza la clasificación usando el clasificador OLS y grafica la frontera de decisión.
Usar la implementación de la clase que usamos anteriormente
'''

from sklearn.preprocessing import PolynomialFeatures

x1_test, x2_test = np.meshgrid(np.linspace(-2, 2.5, 100), np.linspace(-1, 1.5, 100))
x_test = np.array([x1_test, x2_test]).reshape(2, -1).T

features = PolynomialFeatures(1)
X_train = features.fit_transform(x_train)
X_test = features.fit_transform(x_test)

'''
ENTRENAR Y PREDECIR USANDO OLS
'''

plt.figure()
#-----Dibujar los datos---------------------------------
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train)
#-----Dibujar X_test (la malla de fondo para ver las regiones ------------
plt.contour(x1_test, x2_test, y_ols.reshape(100, 100))
#-----Formato de la gráfica------------------------
plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
plt.show()

# %% [markdown]
# SVM con kernel lineal

# %%
'''
Realiza la clasificación en el mismo dataset, usando SVM con kernel lineal y grafica la frontera de decisión.
Puedes usar el código para clasificar y graficar que usamos anteriormente
'''

x1_test, x2_test = np.meshgrid(np.linspace(-2, 2.5, 100), np.linspace(-1, 1.5, 100))
x_test = np.array([x1_test, x2_test]).reshape(2, -1).T

'''
ENTRENAR Y PREDECIR USANDO SVM
'''

plt.figure()
#-----Dibujar los datos---------------------------------
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train)
#-----Dibujar X_test (la malla de fondo para ver las regiones ------------
plt.contour(x1_test, x2_test, y_svm.reshape(100, 100))
#-----Formato de la gráfica------------------------
plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
plt.show()

# %%
plt.figure()
#-----Dibujar los datos---------------------------------
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train)
#-----Dibujar X_test (la malla de fondo para ver las regiones ------------
plt.contour(x1_test, x2_test, y_ols.reshape(100, 100))
plt.contour(x1_test, x2_test, y_svm.reshape(100, 100))
#-----Formato de la gráfica------------------------
plt.gca().set_aspect('equal', adjustable='box')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perceptrón lineal

# %%
from sklearn import preprocessing

features = preprocessing.PolynomialFeatures(1)
X_train = features.fit_transform(x_train)
X_test = features.fit_transform(x_test)

'''
Entrenar y predecir
'''

ex,pr,rec = perceptron.metricas(y_test,y_pred)
print('MÉTRICAS PERCEPTRON:')
print("Exactitud   " + str(ex) + "%")
print("Precision   " + str(pr) + "%")
print("Recall      " + str(rec) + "%")

# --- Graficar ---
fig,ax = grafica(x_train,y_train,x_test,y_test)
perceptron.plot_FD(ax)
plot_FD(perceptronK,show_SV=False)

# %% [markdown]
# # TAREA:
#
#
# Entregar en una notebook lo siguiente:
#
# 1. Perceptron con Kernel Gaussiano
#     * Prueba el modelo PerpcetronKernel con un kernel Gaussiano para distintos valores de Gamma.
#     * Guarda algunos resultados en un archivo (gráficos) y comenta sobre el rol de Gamma en el modelo.
#
# 2. Conclusiones sobre clasificadores lineales. Completar esta notebook, es decir:
#     * Realizar una misma tarea de clasificación sobre alguno de los conjuntos de datos usando los tres modelos de clasificación lineal: OLS, SVM y Perceptrón. Los 3 clasificadores tienen que ser entrenados usando el mismo conjunto de datos.
#     * **EXTRA**: Graficar el conjunto de datos con las 3 fronteras de decisión en la misma imágen.
#     * ¿Cómo puedes mejorar las métricas de clasificación? Reportar los parámetros usados para lograr la mejor clasificación.
#     * Responder las siguientes preguntas: ¿Cuál tuvo mejor rendimiento? ¿Las fronteras de decisión son las mismas? ¿Deberían serlo? ¿Por qué se llaman clasificadores lineales?
#
# *Deadline: Viernes 27 de Mayo.*
